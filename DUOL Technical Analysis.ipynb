# %% [markdown]
# Test

# %%
from openbb import obb
import matplotlib.pyplot as plt

# %%
output = obb.equity.price.historical("DUOL")

# %%
df = output.to_dataframe()
#calculate returns
df['returns'] = df['close'].pct_change()
df.head()
# Out:
#                   open        high         low       close  volume
# date
# 2024-01-23  199.000000  199.000000  190.100006  192.550003  439400
# 2024-01-24  196.000000  196.669998  189.619995  190.570007  433700
# 2024-01-25  193.000000  193.000000  187.229996  191.970001  508600
# 2024-01-26  192.729996  194.399994  191.240005  192.889999  375700
# 2024-01-29  192.759995  194.729996  190.240005  192.770004  622300

# %%
df.plot(y = "close", figsize=(10,5), grid = True, title="DUOL Historical Stock Price")
# Out:
# <Axes: title={'center': 'DUOL Historical Stock Price'}, xlabel='date'>
